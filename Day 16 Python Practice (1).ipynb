# %%
#ORM - Object relational mapping (Translate python to sql)
#Basics ORM
#import create_engine to connect the data
from sqlalchemy import create_engine
engine=create_engine("sqlite:////school.db")
#sql lite database
#file name is school.db
#will be created if not exist
print("database connected")
# Out:
# database connected

# %%
# employee_orm.py

from sqlalchemy.orm import declarative_base, sessionmaker
from sqlalchemy import Column, Integer, String, create_engine

# step 1: create engine (SQLite works fine in Colab)
engine = create_engine("sqlite:///company.db", echo=True)

# step 2: create base class
Base = declarative_base()

# step 3: define table
class Employee(Base):
    __tablename__ = "employees"

    id = Column(Integer, primary_key=True)
    name = Column(String)
    age = Column(Integer)
    department = Column(String)

# step 4: create tables
Base.metadata.create_all(engine)

# step 5: create session
Session = sessionmaker(bind=engine)
session = Session()

# step 6: insert data
e1 = Employee(name="Nobita", age=14, department="Collector")
e2 = Employee(name="Dekesuki", age=15, department="Peon")

session.add(e1)
session.add(e2)
session.commit()

# step 7: fetch & display data
employees = session.query(Employee).all()
for i in employees:
    print(i.id, i.name, i.age, i.department)

employees = session.query(Employee).filter_by(id=1).first()
employees.name = "Gian"
session.commit()
print("employee updated")

employees = session.query(Employee).all()
for i in employees:
    print(i.id, i.name, i.age, i.department)
# Out:
# 2026-02-09 11:24:52,484 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2026-02-09 11:24:52,486 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("employees")
# INFO:sqlalchemy.engine.Engine:PRAGMA main.table_info("employees")
# 2026-02-09 11:24:52,488 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
# 2026-02-09 11:24:52,492 INFO sqlalchemy.engine.Engine COMMIT
# INFO:sqlalchemy.engine.Engine:COMMIT
# 2026-02-09 11:24:52,495 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2026-02-09 11:24:52,500 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, age, department) VALUES (?, ?, ?) RETURNING id
# INFO:sqlalchemy.engine.Engine:INSERT INTO employees (name, age, department) VALUES (?, ?, ?) RETURNING id
# 2026-02-09 11:24:52,502 INFO sqlalchemy.engine.Engine [generated in 0.00015s (insertmanyvalues) 1/2 (ordered; batch not supported)] ('Nobita', 14, 'Collector')
# INFO:sqlalchemy.engine.Engine:[generated in 0.00015s (insertmanyvalues) 1/2 (ordered; batch not supported)] ('Nobita', 14, 'Collector')
# 2026-02-09 11:24:52,506 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, age, department) VALUES (?, ?, ?) RETURNING id
# INFO:sqlalchemy.engine.Engine:INSERT INTO employees (name, age, department) VALUES (?, ?, ?) RETURNING id
# 2026-02-09 11:24:52,509 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/2 (ordered; batch not supported)] ('Dekesuki', 15, 'Peon')
# INFO:sqlalchemy.engine.Engine:[insertmanyvalues 2/2 (ordered; batch not supported)] ('Dekesuki', 15, 'Peon')
# 2026-02-09 11:24:52,511 INFO sqlalchemy.engine.Engine COMMIT
# INFO:sqlalchemy.engine.Engine:COMMIT
# 2026-02-09 11:24:52,520 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2026-02-09 11:24:52,524 INFO sqlalchemy.engine.Engine SELECT employees.id AS employees_id, employees.name AS employees_name, employees.age AS employees_age, employees.department AS employees_department
# FROM employees
# INFO:sqlalchemy.engine.Engine:SELECT employees.id AS employees_id, employees.name AS employees_name, employees.age AS employees_age, employees.department AS employees_department
# FROM employees
# 2026-02-09 11:24:52,526 INFO sqlalchemy.engine.Engine [generated in 0.00288s] ()
# INFO:sqlalchemy.engine.Engine:[generated in 0.00288s] ()
# 1 Gian 14 Collector
# 2 Dekesuki 15 Peon
# 3 Nobita 14 Collector
# 4 Dekesuki 15 Peon
# 5 Nobita 14 Collector
# 6 Dekesuki 15 Peon
# 7 Nobita 14 Collector
# 8 Dekesuki 15 Peon
# 9 Nobita 14 Collector
# 10 Dekesuki 15 Peon
# 11 Nobita 14 Collector
# 12 Dekesuki 15 Peon
# 13 Nobita 14 Collector
# 14 Dekesuki 15 Peon
# 15 Nobita 14 Collector
# 16 Dekesuki 15 Peon
# 17 Nobita 14 Collector
# 18 Dekesuki 15 Peon
# 2026-02-09 11:24:52,535 INFO sqlalchemy.engine.Engine SELECT employees.id AS employees_id, employees.name AS employees_name, employees.age AS employees_age, employees.department AS employees_department
# FROM employees
# WHERE employees.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.Engine:SELECT employees.id AS employees_id, employees.name AS employees_name, employees.age AS employees_age, employees.department AS employees_department
# FROM employees
# WHERE employees.id = ?
#  LIMIT ? OFFSET ?
# 2026-02-09 11:24:52,536 INFO sqlalchemy.engine.Engine [generated in 0.00205s] (1, 1, 0)
# INFO:sqlalchemy.engine.Engine:[generated in 0.00205s] (1, 1, 0)
# 2026-02-09 11:24:52,540 INFO sqlalchemy.engine.Engine COMMIT
# INFO:sqlalchemy.engine.Engine:COMMIT
# employee updated
# 2026-02-09 11:24:52,543 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2026-02-09 11:24:52,545 INFO sqlalchemy.engine.Engine SELECT employees.id AS employees_id, employees.name AS employees_name, employees.age AS employees_age, employees.department AS employees_department
# FROM employees
# INFO:sqlalchemy.engine.Engine:SELECT employees.id AS employees_id, employees.name AS employees_name, employees.age AS employees_age, employees.department AS employees_department
# FROM employees
# 2026-02-09 11:24:52,547 INFO sqlalchemy.engine.Engine [cached since 0.02352s ago] ()
# INFO:sqlalchemy.engine.Engine:[cached since 0.02352s ago] ()
# 1 Gian 14 Collector
# 2 Dekesuki 15 Peon
# 3 Nobita 14 Collector
# 4 Dekesuki 15 Peon
# 5 Nobita 14 Collector
# 6 Dekesuki 15 Peon
# 7 Nobita 14 Collector
# 8 Dekesuki 15 Peon
# 9 Nobita 14 Collector
# 10 Dekesuki 15 Peon
# 11 Nobita 14 Collector
# 12 Dekesuki 15 Peon
# 13 Nobita 14 Collector
# 14 Dekesuki 15 Peon
# 15 Nobita 14 Collector
# 16 Dekesuki 15 Peon
# 17 Nobita 14 Collector
# 18 Dekesuki 15 Peon
